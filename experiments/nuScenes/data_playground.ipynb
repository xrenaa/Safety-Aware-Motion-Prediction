# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

data_dir = "./train/"
data_list = sorted(glob.glob(os.path.join(data_dir, "*.npz")))

index = 0
data = np.load(data_list[index])

input_img = data["input"]
plt.imshow(input_img)
plt.show()

target = data["target"]
plt.imshow(target)
plt.show()

unseen_mask = data["attention"]
plt.imshow(unseen_mask)
plt.show()
